# %%
import geopandas as gpd

# %%
census_tracts = gpd.read_file ('../../data/ejsm_scores_shp/census tract (2012).shp')

# %%
type(census_tracts)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
census_tracts.head()
# Out:
#                             slug                   set                 kind  \
# 0  06037101110-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 1  06037101122-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 2  06037101210-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 3  06037101220-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
# 4  06037101300-census-tract-2012  Census Tracts (2012)  Census Tract (2012)
#
#     external_i     name                       display_na     INTPTLAT NAME_1  \
# 0  06037101110  1011.10  06037101110 Census Tract (2012)  +34.2594737   None
# 1  06037101122  1011.22  06037101122 Census Tract (2012)  +34.2677213   None
# 2  06037101210  1012.10  06037101210 Census Tract (2012)  +34.2529724   None
# 3  06037101220  1012.20  06037101220 Census Tract (2012)  +34.2516085   None
# 4  06037101300     1013  06037101300 Census Tract (2012)  +34.2487732   None
#
# ...

# %%
census_tracts.tail()
# Out:
#                                slug                   set  \
# 2341  06037980031-census-tract-2012  Census Tracts (2012)
# 2342  06037980033-census-tract-2012  Census Tracts (2012)
# 2343  06037990100-census-tract-2012  Census Tracts (2012)
# 2344  06037990200-census-tract-2012  Census Tracts (2012)
# 2345  06037990300-census-tract-2012  Census Tracts (2012)
#
#                      kind   external_i     name  \
# 2341  Census Tract (2012)  06037980031  9800.31
# 2342  Census Tract (2012)  06037980033  9800.33
# 2343  Census Tract (2012)  06037990100     9901
# 2344  Census Tract (2012)  06037990200     9902
# 2345  Census Tract (2012)  06037990300     9903
#
#                            display_na     INTPTLAT NAME_1      INTPTLON  \
# 2341  06037980031 Census Tract (2012)  +33.7338344   None  -118.2627274
# 2342  06037980033 Census Tract (2012)  +33.7443155   None  -118.2203101
# 2343  06037990100 Census Tract (2012)  +33.9991909   None  -118.7921876
# ...

# %%
census_tracts.sample(100)
# Out:
#                                slug                   set  \
# 2295  06037920118-census-tract-2012  Census Tracts (2012)
# 767   06037237201-census-tract-2012  Census Tracts (2012)
# 1796  06037554514-census-tract-2012  Census Tracts (2012)
# 127   06037119001-census-tract-2012  Census Tracts (2012)
# 1205  06037406800-census-tract-2012  Census Tracts (2012)
# ...                             ...                   ...
# 1665  06037540800-census-tract-2012  Census Tracts (2012)
# 15    06037104103-census-tract-2012  Census Tracts (2012)
# 2310  06037920336-census-tract-2012  Census Tracts (2012)
# 564   06037209103-census-tract-2012  Census Tracts (2012)
# 432   06037191301-census-tract-2012  Census Tracts (2012)
#
#                      kind   external_i     name  \
# 2295  Census Tract (2012)  06037920118  9201.18
# 767   Census Tract (2012)  06037237201  2372.01
# 1796  Census Tract (2012)  06037554514  5545.14
# 127   Census Tract (2012)  06037119001  1190.01
# ...

# %%
census_tracts.dtypes
# Out:
# slug            object
# set             object
# kind            object
# external_i      object
# name            object
# display_na      object
# INTPTLAT        object
# NAME_1          object
# INTPTLON        object
# FUNCSTAT        object
# GEOID           object
# AWATER          object
# COUNTYFP        object
# NAMELSAD        object
# MTFCC           object
# TRACTCE         object
# STATEFP         object
# ALAND           object
# geometry      geometry
# dtype: object

# %%
census_tracts.shape
# Out:
# (2346, 19)

# %%
census_tracts.columns.to_list()
# Out:
# ['slug',
#  'set',
#  'kind',
#  'external_i',
#  'name',
#  'display_na',
#  'INTPTLAT',
#  'NAME_1',
#  'INTPTLON',
#  'FUNCSTAT',
#  'GEOID',
#  'AWATER',
#  'COUNTYFP',
#  'NAMELSAD',
#  'MTFCC',
#  'TRACTCE',
#  'STATEFP',
#  'ALAND',
#  'geometry']

# %%
census_tracts.plot()

# %%
import folium

# %%
latitude = census_tracts.LAT.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-ce53b5877744> in <module>
# ----> 1 latitude = census_tracts.LAT.mean()
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'LAT'
